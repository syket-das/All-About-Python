# %% [markdown]
# <a href="https://colab.research.google.com/github/syket-das/All-About-Python/blob/main/dsa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
